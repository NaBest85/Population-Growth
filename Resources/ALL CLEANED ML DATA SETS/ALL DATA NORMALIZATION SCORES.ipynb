# %%
import pandas as pd
from openpyxl import load_workbook

# Provide the file path
file_path = "/Users/prodigygoldbooks/Desktop/ALL DATA NORMALIZATION SCORES.xlsx"

# Load the workbook
workbook = load_workbook(filename=file_path)

# Get all worksheet names
worksheet_names = workbook.sheetnames

# Create a dictionary to store all worksheets as DataFrames
dfs = {}

# Read each worksheet into a DataFrame
for name in worksheet_names:
    dfs[name] = pd.read_excel(file_path, sheet_name=name)
    
#Drop NaN
    df = df.dropna()
    df = df.dropna(axis=1)

# Display each DataFrame
for name, df in dfs.items():
    print(f"Worksheet: {name}")
    print(df.head())
    print('\n')
# Out:
# Worksheet: RANKINGS
#         STATE  SUM OF WEIGHTED SCORES  UNSORTED RANK  Unnamed: 3  \
# 0     Alabama                0.024394             48         NaN
# 1      Alaska                0.029333             34         NaN
# 2     Arizona                0.028333             37         NaN
# 3    Arkansas                0.040000              8         NaN
# 4  California                0.038889             13         NaN
#
#   FINAL STATE RANKS  Unnamed: 5  SORTED RANK
# 0            Nevada    0.045556            1
# 1          New York    0.044825            2
# 2            Kansas    0.044722            3
# 3     West Virginia    0.043922            4
# 4      Rhode Island    0.042778            5
#
#
# Worksheet: MALE UNEMPLOYMENT RATE
#   UNEMPLOYMENT RATE (MEN)  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0                   State      2020.0      2021.0      2022.0    MINIMUM
# 1                 Alabama        72.4        72.3        74.5       72.3
# ...
