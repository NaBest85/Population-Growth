# %%
import pandas as pd

# %%
#Load each csv into a DataFrame
df_2022 = pd.read_csv('Household Income 2022.csv')
df_2021 = pd.read_csv('Household Income 2021.csv')
df_2020 = pd.read_csv('Household Income 2020.csv')

# %%
#create a year column for each DataFrame to show the year
df_2022['Year'] = 2022
df_2021['Year'] = 2021
df_2020['Year'] = 2020

# %%
#cooncatenate the DataFrames
combined_df = pd.concat([df_2022, df_2021, df_2020], ignore_index=True)
combined_df.head()
# Out:
#          NAME  Households Total Income  Households with Income under $10,000  \
# 0     Alabama                  2016448                                   7.6
# 1      Alaska                   274574                                   4.4
# 2     Arizona                  2850377                                   5.4
# 3    Arkansas                  1216207                                   7.3
# 4  California                 13550586                                   4.8
#
#    Households with Income of $200,000 or more  Year
# 0                                         6.7  2022
# 1                                        11.4  2022
# 2                                         9.6  2022
# 3                                         5.5  2022
# 4                                        18.0  2022

# %%
combined_df.to_csv('Combined_Household_Income.csv', index=False)

# %%
combined_df = pd.read_csv('Combined_Household_Income.csv')
combined_df
# Out:
#               NAME  Households Total Income  \
# 0          Alabama                  2016448
# 1           Alaska                   274574
# 2          Arizona                  2850377
# 3         Arkansas                  1216207
# 4       California                 13550586
# ..             ...                      ...
# 151     Washington                  2905822
# 152  West Virginia                   734235
# 153      Wisconsin                  2377935
# 154        Wyoming                   233231
# 155    Puerto Rico                  1205749
#
#      Households with Income under $10,000  \
# 0                                     7.6
# 1                                     4.4
# 2                                     5.4
# 3                                     7.3
# 4                                     4.8
# ..                                    ...
# 151                                   4.4
# 152                                   8.5
# 153                                   4.6
# 154                                   5.2
# 155                                  26.4
#
#      Households with Income of $200,000 or more  Year
# 0                                           6.7  2022
# 1                                          11.4  2022
# 2                                           9.6  2022
# 3                                           5.5  2022
# 4                                          18.0  2022
# ..                                          ...   ...
# 151                                        10.5  2020
# 152                                         3.1  2020
# 153                                         5.2  2020
# 154                                         5.0  2020
# 155                                         1.0  2020
#
# [156 rows x 5 columns]
